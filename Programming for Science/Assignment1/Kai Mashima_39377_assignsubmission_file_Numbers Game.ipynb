# %%
import random

#functions
def sucker():
    print("You are bad at following instructions. Please LEAVE NOW!!!!")
    
def otherEnd():
    print("Your number has NOT been determined. YOU ARE BAD AT FOLLOWING INSTRUCTIONS.")

def end():
    print("Your number has been determined. Thank you for playing.")
    
def printStatements(number):   
    if (number != 1):
        if (number == 2):
            print("The number is Two.")
        else:
            print("The number is Not Two.")
            if (number >= 10):
                print("The number is a Double Digit.")
                if (number > 11):
                    print("The number is Twelve or Thirteen.")
                    if (number == 13):
                        print("The number is Thirteen.")
                        end()
                    else:
                        print("The number is Twelve.")
                        end()
                else:
                    print("The number is Eleven.")
                    end()
            else:
                print("The number is a Single Digit.")
                if (number == 2 or number == 4 or number == 6 or number == 8):
                    print("The number is Even.")
                    if (number <= 4):
                        print("The number is Two or Four.")
                        if (number < 3):
                            print("The number is Two.")
                            end()
                        else:
                            print("The number is Four.")
                            end()
                    elif (number >= 5):
                        print("The number is Six or Eight.")
                        if (number > 7):
                            print("The number is Eight.")
                            end()
                        else:
                            print("The number is Six.")
                            end()
                else:
                    print("The number is Odd.")
                    if (number < 5):
                        print("The number is One or Three.")
                        if (number < 2):
                            print("The number is One.")
                            end()
                        else:
                            print("The number is Three.")
                            end()
                    elif (number == 5):
                        print("The number is Five.")
                        end()
                    if (number > 5):
                        print("The number Seven or Nine.")
                        if (number > 8):
                            print("The number is Nine.")
                            end()
                        else:
                            print("The number is Seven.")
                            end()
    else:
        print("One")
        
def game():
    inputNumber = input("Input a number between 1 and 13: ")
    number = int(inputNumber)
    if (number > 13 or number < 1):
        print("Invalid input.")
        sucker()
        one = input("Are you bad at following instruction. Yes or Yes?: ")
        two = input("Are you bad at following instruction. Yes or Yes?: ")
        three = input("Are you bad at following instruction. Yes or Yes?: ")
        four = input("Are you bad at following instruction. Yes or Yes?: ")
        five = input("Are you bad at following instruction. Yes or Yes?: ")
        six = input("Are you bad at following instruction. Yes or Yes?: ") 
        print("I AM LEAVING YOU!")
        otherEnd()
    else: 
        printStatements(number)
    print("----------------------------------------------------------------")
        
#running code
numberOfPlays = input("How many times would you like to play? ")
plays = int(numberOfPlays)
i = 0
while (i <= plays):
    game()
    i = i + 1
# Out:
# How many times would you like to play? 2
# Input a number between 1 and 13: 3
# The number is Not Two.
# The number is a Single Digit.
# The number is Odd.
# The number is One or Three.
# The number is Three.
# Your number has been determined. Thank you for playing.
# ----------------------------------------------------------------
# Input a number between 1 and 13: 4
# The number is Not Two.
# The number is a Single Digit.
# The number is Even.
# The number is Two or Four.
# The number is Four.
# Your number has been determined. Thank you for playing.
# ----------------------------------------------------------------
# Input a number between 1 and 13: 7
# The number is Not Two.
# The number is a Single Digit.
# The number is Odd.
# The number Seven or Nine.
# The number is Seven.
# Your number has been determined. Thank you for playing.
# ----------------------------------------------------------------
